# %% [markdown]
# # Probability distribution as a function of time
#
# For a set of times, shows the probabilities for the true class and a handful of confusing classes as a function of time, for one classifier and one true class.
#
# Supposed to be a whole bunch of violin plots.  Right now, it's not very pretty, but the basic idea is plotted.

# %%
# %matplotlib inline
import sys
import os
import logging
import numpy
import pandas
import matplotlib
from matplotlib import pyplot
import seaborn
import sklearn
import sklearn.metrics

from metric_querier import ELAsTiCCMetricsQuerier

# %%
logger = logging.getLogger(__name__)
if not logger.hasHandlers():
    _logout = logging.StreamHandler( sys.stderr )
    logger.addHandler( _logout )
    _formatter = logging.Formatter( f'[%(asctime)s - %(levelname)s] - %(message)s', datefmt='%Y-%m-%d %H:%M:%S' )
    _logout.setFormatter( _formatter )

logger.setLevel( logging.DEBUG )

# %%
username = "rknop"
with open( os.path.join( os.getenv("HOME"), "secrets", "tom_"+username+"_passwd" ) ) as ifp:
    password = ifp.readline().strip()
    
emq = ELAsTiCCMetricsQuerier( tomusername=username, tompasswd=password, logger=logger )

# %%
# Run help(ELAsTiCCMetricsQuerier) for lots of information
probhist = emq.probhist()
# Out:
# [2023-04-26 07:05:36 - DEBUG] - Sending query to get probabilistic metrics histogram table
# [2023-04-26 07:05:49 - DEBUG] - Got response, pandifying
# [2023-04-26 07:05:51 - DEBUG] - Done

# %%
# This one is important
# For each true class, a list of "confusion classes" to plot alongside it.
# The right thing to do is hard... you have to know what's in the data already!

confusionclasses = {
    # Ia -> Ia, Ibc, II, PISN, SLSN, TDE
    111: [ 111, 112, 113, 135, 131, 132 ],
    # 111: [ 111, 0 ],
    113: [ 111, 112, 113, 135, 131, 132 ]
}

confusioncolors = [ 'green', 'red', 'blue', 'orange', 'darkviolet', 'darkturquoise' ]

# %%
# cferstodo = list( emq.classifier_info.keys() )
cferstodo = [ 40, 89, 44 ]
# cferstodo = [ 78 ]
# cferstodo = [ 47, 57, 68, 75, 78 ]
trueclasstodo = [ 111, 112, 113, 131 ]
# trueclasstodo = [ 111 ]

# Every time bin is overwhelming.  Choose some time bins to do
# Let's do -10 days, 0 days, 30 days, 60 days, and >=100 days
tbinstodo = [ 5, 7, 13, 19, 27 ]

print( "Going to do classifiers:" )
for c in cferstodo:
    print( f"  {emq.classifier_info[c]}" )
print( f"Going to do classes: {[emq.classname[i] for i in trueclasstodo]}" )
# Out:
# Going to do classifiers:
#   {'classifierId': 40, 'brokerName': 'ALeRCE', 'brokerVersion': '3.1.0', 'classifierName': 'balto', 'classifierParams': '3.1.0'}
#   {'classifierId': 89, 'brokerName': 'AMPEL', 'brokerVersion': 'v0.4', 'classifierName': 'ElasticcLiveSNGuessParsnipPrior', 'classifierParams': 'XGBUnified+Parsnip05'}
#   {'classifierId': 44, 'brokerName': 'ANTARES', 'brokerVersion': '2.0.0', 'classifierName': 'LiCuParsnip_filter', 'classifierParams': 'v2'}
# Going to do classes: ['Ia', 'Ib/c', 'II', 'SLSN']

# %%
for cfer in cferstodo:
    brokername = emq.classifier_info[cfer]['brokerName']
    brokerversion = emq.classifier_info[cfer]['brokerVersion']
    classifiername = emq.classifier_info[cfer]['classifierName']
    classifierparams = emq.classifier_info[cfer]['classifierParams']
    cfertitle = f'{brokername} {brokerversion} {classifiername} {classifierparams}'
    for trueclass in trueclasstodo:
        logger.debug( f"doing cfer {cfer}, true class {emq.classname[trueclass]}" )
        subdf = probhist.xs( ( cfer, trueclass ), level=( 'classifierId', 'trueClassId' ) )
        probdf = subdf / subdf.groupby( ['classId', 'tbin'] ).sum()
        probdf.reset_index( inplace=True )
        probdf.set_index( ['tbin', 'probbin', 'classId'], inplace=True )
        # Extract just the t bins to do
        probdf = probdf.loc[ pandas.IndexSlice[ tbinstodo, :, : ] ]
        # Calculate probabilities
        probdf.reset_index( inplace=True )
        probdf['prob'] = emq.probbin_val( probdf['probbin'] )
        probdf.set_index( [ 'tbin', 'classId' ], inplace=True )
        
        fig = pyplot.figure( figsize=(16, 6), tight_layout=True )
        ax = fig.add_subplot( 1, 1, 1 )
        ax.set_title( f"{cfertitle}\nTrue class {emq.classname[trueclass]}" )
        
        tdex = numpy.arange( len(tbinstodo) )
        ax.set_xlim( tdex[0] - 1 , tdex[-1] + 1 )
        ax.set_ylim( 0., 1.)
        ax.set_xticks( tdex )
        ax.set_xticklabels( [ emq.tbin_val(i) for i in tbinstodo ] )
        ax.set_xlabel( 'Δt (days)' )
        ax.set_ylabel( 'probability' )
        
        # I'm doing violin plots "manually" here since the actual violin plot methods
        # assume you're feeding it raw data, but what we have is binned data.
        
        for ti in tdex:
            for confdex in range(len(confusionclasses[trueclass])):
                confoff = 0.85 * ( confdex - len(confusionclasses[trueclass])/2. ) / len(confusionclasses[trueclass])
                thist = probdf.xs( ( tbinstodo[ti], confusionclasses[trueclass][confdex] ), level=( 'tbin', 'classId' ) )
                # display(thist)
                yvals = thist['prob']
                xvals = ti + thist['count']
                
                if ( ti == 0 ) :
                    ax.plot( confoff + ti + 0.4*thist['count'], thist['prob'], color=confusioncolors[confdex],
                             label=emq.classname[ confusionclasses[trueclass][confdex] ] )
                else:
                    ax.plot( confoff + ti + 0.4*thist['count'], thist['prob'], color=confusioncolors[confdex] )
                ax.plot( confoff + ti - 0.4*thist['count'], thist['prob'], color=confusioncolors[confdex] )
            
        ax.legend()
        fig.show()
# Out:
# [2023-04-13 11:46:42 - DEBUG] - doing cfer 40, true class Ia
# [2023-04-13 11:46:42 - DEBUG] - doing cfer 40, true class Ib/c
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_62332/3847964812.py in <module>
#      34
#      35         for ti in tdex:
# ---> 36             for confdex in range(len(confusionclasses[trueclass])):
#      37                 confoff = 0.85 * ( confdex - len(confusionclasses[trueclass])/2. ) / len(confusionclasses[trueclass])
#      38                 thist = probdf.xs( ( tbinstodo[ti], confusionclasses[trueclass][confdex] ), level=( 'tbin', 'classId' ) )
#
# KeyError: 112

# %%
# Out:
#                                                count
# classifierId trueClassId classId tbin probbin
# 36           111         0       1    21           4
#                                  2    21         133
#                                  3    21        2217
#                                  4    21        3333
#                                  5    21        2887
# ...                                              ...
# 89           221         135     27   16        1524
#                                       17        1464
#                                       18        1669
#                                       19        1412
#                                       20        1327
#
# [1226274 rows x 1 columns]

# %%
thing = probhist.xs( ( 89, 113 ), level=('classifierId','trueClassId') ).groupby( [ 'tbin' ] ).sum().reset_index()
thing['t'] = emq.tbin_val( thing['tbin'] )
thing
# Out:
#     tbin    count      t
# 0      0   804320  -32.5
# 1      1   209888  -27.5
# 2      2   253872  -22.5
# 3      3   370144  -17.5
# 4      4   786144  -12.5
# 5      5  1790256   -7.5
# 6      6  4266560   -2.5
# 7      7  7417072    2.5
# 8      8  7676736    7.5
# 9      9  7045600   12.5
# 10    10  6206288   17.5
# 11    11  5379216   22.5
# 12    12  4568496   27.5
# 13    13  3884096   32.5
# 14    14  3301728   37.5
# 15    15  2879584   42.5
# 16    16  2551552   47.5
# 17    17  2320128   52.5
# 18    18  2105824   57.5
# 19    19  1952432   62.5
# 20    20  1809088   67.5
# 21    21  1673744   72.5
# 22    22  1578640   77.5
# 23    23  1459888   82.5
# 24    24  1364096   87.5
# 25    25  1248032   92.5
# 26    26  1113440   97.5
# 27    27  6830016  102.5

# %%
pyplot.plot( thing['t'], thing['count'] )

# %%
[ f'{k} {v}' for k,v in emq.classifier_info.items() if v['brokerName']=='Fink' ]
# Out:
# ["45 {'classifierId': 45, 'brokerName': 'Fink', 'brokerVersion': '2.4', 'classifierName': 'AGN classifier version 1.0', 'classifierParams': 'Probability to be an AGN based on a Random Forest classifier'}",
#  "46 {'classifierId': 46, 'brokerName': 'Fink', 'brokerVersion': '2.4', 'classifierName': 'AGN classifier version 1.0', 'classifierParams': 'Probability to NOT be an AGN based on a Random Forest classifier'}",
#  "47 {'classifierId': 47, 'brokerName': 'Fink', 'brokerVersion': '2.4', 'classifierName': 'SuperNNova SN Ia classifier version 1.0', 'classifierParams': 'Probability to be a SN Ia based on SuperNNova'}",
#  "48 {'classifierId': 48, 'brokerName': 'Fink', 'brokerVersion': '2.4', 'classifierName': 'SuperNNova SN Ia classifier version 1.0', 'classifierParams': 'Probability to NOT be a SN Ia based on SuperNNova'}",
#  "49 {'classifierId': 49, 'brokerName': 'Fink', 'brokerVersion': '2.4', 'classifierName': 'SuperNNova broad classifier version 1.0', 'classifierParams': 'Level 1 classifier based on SuperNNova'}",
#  "50 {'classifierId': 50, 'brokerName': 'Fink', 'brokerVersion': '2.4', 'classifierName': 'CATS broad classifier version 1.0', 'classifierParams': 'Level 1 classifier based on the CBPF Algorithm for Transient Search'}",
#  "51 {'classifierId': 51, 'brokerName': 'Fink', 'brokerVersion': '2.4', 'classifierName': 'CATS fine classifier version 1.0', 'classifierParams': 'Level 2 classifier based on the CBPF Algorithm for Transient Search'}",
#  "52 {'classifierId': 52, 'brokerName': 'Fink', 'brokerVersion': '2.4', 'classifierName': 'EarlySN classifier version 1.0', 'classifierParams': 'Probability to be an early SN Ia based on a Random Forest classifier'}",
#  "53 {'classifierId': 53, 'brokerName': 'Fink', 'brokerVersion': '2.4', 'classifierName': 'EarlySN classifier version 1.0', 'classifierParams': 'Probability to NOT be an early SN Ia based on a Random Forest classifier'}",
#  "54 {'classifierId': 54, 'brokerName': 'Fink', 'brokerVersion': '2.4', 'classifierName': 'T2 classifier version 1.0', 'classifierParams': 'Level 1 classifier based on Time-Series Transformer'}",
#  "56 {'classifierId': 56, 'brokerName': 'Fink', 'brokerVersion': '2.5', 'classifierName': 'AGN classifier', 'classifierParams': 'version 1.0'}",
#  "57 {'classifierId': 57, 'brokerName': 'Fink', 'brokerVersion': '2.5', 'classifierName': 'SuperNNova SN Ia classifier', 'classifierParams': 'version 1.0'}",
#  "58 {'classifierId': 58, 'brokerName': 'Fink', 'brokerVersion': '2.5', 'classifierName': 'SuperNNova broad classifier version 1.0', 'classifierParams': 'Level 1 classifier based on SuperNNova'}",
#  "59 {'classifierId': 59, 'brokerName': 'Fink', 'brokerVersion': '2.5', 'classifierName': 'CATS broad classifier version 1.0', 'classifierParams': 'Level 1 classifier based on the CBPF Algorithm for Transient Search'}",
#  "60 {'classifierId': 60, 'brokerName': 'Fink', 'brokerVersion': '2.5', 'classifierName': 'CATS fine classifier version 1.0', 'classifierParams': 'Level 2 classifier based on the CBPF Algorithm for Transient Search'}",
#  "61 {'classifierId': 61, 'brokerName': 'Fink', 'brokerVersion': '2.5', 'classifierName': 'EarlySN classifier', 'classifierParams': 'version 1.0'}",
#  "62 {'classifierId': 62, 'brokerName': 'Fink', 'brokerVersion': '2.5', 'classifierName': 'T2 classifier version 1.0', 'classifierParams': 'Level 1 classifier based on Time-Series Transformer'}",
#  "63 {'classifierId': 63, 'brokerName': 'Fink', 'brokerVersion': '2.5', 'classifierName': 'AGN classifier', 'classifierParams': 'version 1.1'}",
#  "67 {'classifierId': 67, 'brokerName': 'Fink', 'brokerVersion': '2.6', 'classifierName': 'AGN classifier', 'classifierParams': 'version 1.2'}",
#  "68 {'classifierId': 68, 'brokerName': 'Fink', 'brokerVersion': '2.6', 'classifierName': 'SuperNNova SN Ia classifier', 'classifierParams': 'version 1.1'}",
#  "69 {'classifierId': 69, 'brokerName': 'Fink', 'brokerVersion': '2.6', 'classifierName': 'SuperNNova broad classifier', 'classifierParams': 'version 1.1'}",
#  "70 {'classifierId': 70, 'brokerName': 'Fink', 'brokerVersion': '2.6', 'classifierName': 'CATS fine classifier', 'classifierParams': 'version 2.0'}",
#  "71 {'classifierId': 71, 'brokerName': 'Fink', 'brokerVersion': '2.6', 'classifierName': 'EarlySN classifier', 'classifierParams': 'version 1.0'}",
#  "72 {'classifierId': 72, 'brokerName': 'Fink', 'brokerVersion': '2.6', 'classifierName': 'T2 classifier', 'classifierParams': 'version 1.0'}",
#  "74 {'classifierId': 74, 'brokerName': 'Fink', 'brokerVersion': '2.7', 'classifierName': 'AGN classifier', 'classifierParams': 'version 1.2'}",
#  "75 {'classifierId': 75, 'brokerName': 'Fink', 'brokerVersion': '2.7', 'classifierName': 'SuperNNova SN Ia classifier', 'classifierParams': 'version 1.1'}",
#  "76 {'classifierId': 76, 'brokerName': 'Fink', 'brokerVersion': '2.7', 'classifierName': 'SuperNNova broad classifier', 'classifierParams': 'version 1.1'}",
#  "77 {'classifierId': 77, 'brokerName': 'Fink', 'brokerVersion': '2.7', 'classifierName': 'CATS fine classifier', 'classifierParams': 'version 2.0'}",
#  "78 {'classifierId': 78, 'brokerName': 'Fink', 'brokerVersion': '2.7', 'classifierName': 'EarlySN classifier', 'classifierParams': 'version 1.0'}",
#  "79 {'classifierId': 79, 'brokerName': 'Fink', 'brokerVersion': '2.7', 'classifierName': 'T2 classifier', 'classifierParams': 'version 1.0'}",
#  "84 {'classifierId': 84, 'brokerName': 'Fink', 'brokerVersion': '2.7', 'classifierName': 'AGN classifier', 'classifierParams': 'version 2.0'}",
#  "85 {'classifierId': 85, 'brokerName': 'Fink', 'brokerVersion': '2.7', 'classifierName': 'CATS fine classifier', 'classifierParams': 'version 3.0'}"]
